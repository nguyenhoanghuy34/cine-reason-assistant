# %%
import pandas as pd

file_path = r"D:\Subject\HOME_TEST\cine-reason-assistant\backend\data\ml-latest-small-filtered\tags.csv"

df = pd.read_csv(file_path)

df.head(10)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200
# 5       2    89774        Tom Hardy  1445715205
# 6      18      431        Al Pacino  1462138765
# 7      18      431         gangster  1462138749
# 8      18      431            mafia  1462138755
# 9      18     1221        Al Pacino  1461699306
